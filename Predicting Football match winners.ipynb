# %%
#Importing the data
import pandas as pd
matches = pd.read_csv("~/matches.csv",index_col = 0)
matches.head()
# Out:
#          date   time            comp        round  day venue result  gf  ga  \
# 1  2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away      L   0   1
# 2  2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home      W   5   0
# 3  2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home      W   5   0
# 4  2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away      W   1   0
# 6  2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home      D   0   0
#
#          opponent  ...  match report  notes    sh   sot  dist   fk   pk pkatt  \
# 1       Tottenham  ...  Match Report    NaN  18.0   4.0  16.9  1.0  0.0   0.0
# 2    Norwich City  ...  Match Report    NaN  16.0   4.0  17.3  1.0  0.0   0.0
# 3         Arsenal  ...  Match Report    NaN  25.0  10.0  14.3  0.0  0.0   0.0
# 4  Leicester City  ...  Match Report    NaN  25.0   8.0  14.0  0.0  0.0   0.0
# 6     Southampton  ...  Match Report    NaN  16.0   1.0  15.7  1.0  0.0   0.0
#
#    season             team
# 1    2022  Manchester City
# 2    2022  Manchester City
# 3    2022  Manchester City
# 4    2022  Manchester City
# 6    2022  Manchester City
#
# [5 rows x 27 columns]

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf                int64
# ga                int64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk              float64
# pkatt           float64
# season            int64
# team             object
# dtype: object

# %%
#Creating predictors fot the algorithm
matches["date"] = pd.to_datetime(matches["date"])
matches["venue_code"] = matches["venue"].astype("category").cat.codes
matches["opp_code"] = matches["opponent"].astype("category").cat.codes
matches["hour"] = matches["time"].str.replace(":.+","",regex = True).astype("int")
matches["day_code"] = matches["date"].dt.dayofweek
matches["Target"] = (matches["result"] == "W").astype("int")
matches.head()
# Out:
#         date   time            comp        round  day venue result  gf  ga  \
# 1 2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away      L   0   1
# 2 2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home      W   5   0
# 3 2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home      W   5   0
# 4 2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away      W   1   0
# 6 2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home      D   0   0
#
#          opponent  ...   fk   pk  pkatt  season             team venue_code  \
# 1       Tottenham  ...  1.0  0.0    0.0    2022  Manchester City          0
# 2    Norwich City  ...  1.0  0.0    0.0    2022  Manchester City          1
# 3         Arsenal  ...  0.0  0.0    0.0    2022  Manchester City          1
# 4  Leicester City  ...  0.0  0.0    0.0    2022  Manchester City          0
# 6     Southampton  ...  1.0  0.0    0.0    2022  Manchester City          1
#
#   opp_code hour  day_code  Target
# 1       16   16         6       0
# 2       14   15         5       1
# 3        0   12         5       1
# 4        9   15         5       1
# 6       15   15         5       0
#
# [5 rows x 32 columns]

# %%
#Creating the model
from sklearn.ensemble import RandomForestClassifier 
rf = RandomForestClassifier(n_estimators = 100,min_samples_split = 20, random_state = 1)
train = matches[matches["date"] < "2022-03-01"]
test = matches[matches["date"] > "2022-03-01"]

predictors = ["venue_code","opp_code","hour","day_code"]
rf.fit(train[predictors],train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=20, random_state=1)

# %%
#Using accuracy metric
from sklearn.metrics import accuracy_score
preds = rf.predict(test[predictors])
acc = accuracy_score(test["Target"],preds)
print("accuracy is ",acc)
combined = pd.DataFrame(dict(actual=test["Target"],prediction = preds))
pd.crosstab(index = combined["actual"],columns = combined["prediction"])
# Out:
# accuracy is  0.6341463414634146
# prediction    0   1
# actual
# 0           240  48
# 1           132  72

# %%
#Using precision_metric
from sklearn.metrics import precision_score
precision_score(test["Target"],preds)
# Out:
# 0.6

# %%
#Improving presion with rolling averages
grouped_matches = matches.groupby("team")
group = grouped_matches.get_group("Manchester City")
group.head()
# Out:
#         date   time            comp        round  day venue result  gf  ga  \
# 1 2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away      L   0   1
# 2 2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home      W   5   0
# 3 2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home      W   5   0
# 4 2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away      W   1   0
# 6 2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home      D   0   0
#
#          opponent  ...   fk   pk  pkatt  season             team venue_code  \
# 1       Tottenham  ...  1.0  0.0    0.0    2022  Manchester City          0
# 2    Norwich City  ...  1.0  0.0    0.0    2022  Manchester City          1
# 3         Arsenal  ...  0.0  0.0    0.0    2022  Manchester City          1
# 4  Leicester City  ...  0.0  0.0    0.0    2022  Manchester City          0
# 6     Southampton  ...  1.0  0.0    0.0    2022  Manchester City          1
#
#   opp_code hour  day_code  Target
# 1       16   16         6       0
# 2       14   15         5       1
# 3        0   12         5       1
# 4        9   15         5       1
# 6       15   15         5       0
#
# [5 rows x 32 columns]

# %%
def rolling_averages(group,cols,new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3,closed ='left').mean()
    group[new_cols]=rolling_stats
    group = group.dropna(subset = new_cols)
    return group

cols = ["gf","ga","sh","sot","dist","fk","pk","pkatt"]
new_cols = [f"{c}_rolling" for c in cols]


rolling_averages(group,cols,new_cols)
new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
matches_rolling = matches.groupby("team").apply(lambda x:rolling_averages(x,cols,new_cols))
matches_rolling = matches_rolling.droplevel("team")
matches_rolling.index = range(matches_rolling.shape[0])
matches_rolling.dtypes
# Out:
# date             datetime64[ns]
# time                     object
# comp                     object
# round                    object
# day                      object
# venue                    object
# result                   object
# gf                        int64
# ga                        int64
# opponent                 object
# xg                      float64
# xga                     float64
# poss                    float64
# attendance              float64
# captain                  object
# formation                object
# referee                  object
# match report             object
# notes                   float64
# sh                      float64
# sot                     float64
# dist                    float64
# fk                      float64
# pk                      float64
# pkatt                   float64
# season                    int64
# team                     object
# venue_code                 int8
# opp_code                   int8
# hour                      int64
# day_code                  int64
# Target                    int64
# gf_rolling              float64
# ga_rolling              float64
# sh_rolling              float64
# sot_rolling             float64
# dist_rolling            float64
# fk_rolling              float64
# pk_rolling              float64
# pkatt_rolling           float64
# dtype: object

# %%
#Making the model more robust and scalable
def make_predictors(data,predictors):
    train = data[data["date"] < "2022-03-01"]
    test = data[data["date"] > "2022-03-01"]
    rf.fit(train[predictors],train["Target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["Target"],prediction = preds))
    precision = precision_score(test["Target"],preds)
    
    return combined, precision

# %%
predictors+new_cols

combined,precision = make_predictors(matches_rolling,predictors+new_cols)
precision
# Out:
# 0.6422764227642277

# %%
combined
# Out:
#       actual  prediction
# 45         1           1
# 46         1           1
# 47         1           0
# 48         1           0
# 49         0           1
# ...      ...         ...
# 1455       0           0
# 1456       0           0
# 1457       0           0
# 1458       0           0
# 1459       0           0
#
# [492 rows x 2 columns]

# %%
combined = combined.merge(matches_rolling[["date","team","opponent","result"]],left_index =True,right_index = True)
combined
# Out:
#       actual  prediction       date                     team         opponent  \
# 45         1           1 2022-03-06                  Arsenal          Watford
# 46         1           1 2022-03-06                  Arsenal          Watford
# 47         1           0 2022-03-13                  Arsenal   Leicester City
# 48         1           0 2022-03-13                  Arsenal   Leicester City
# 49         0           1 2022-03-16                  Arsenal        Liverpool
# ...      ...         ...        ...                      ...              ...
# 1455       0           0 2022-05-11  Wolverhampton Wanderers  Manchester City
# 1456       0           0 2022-05-15  Wolverhampton Wanderers     Norwich City
# 1457       0           0 2022-05-15  Wolverhampton Wanderers     Norwich City
# 1458       0           0 2022-05-22  Wolverhampton Wanderers        Liverpool
# 1459       0           0 2022-05-22  Wolverhampton Wanderers        Liverpool
#
#      result
# 45        W
# 46        W
# 47        W
# 48        W
# 49        L
# ...     ...
# 1455      L
# 1456      D
# 1457      D
# 1458      L
# 1459      L
#
# [492 rows x 6 columns]

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {"Brighton and Hove Albion": "Brighton", "Manchester United": "Manchester Utd", "Newcastle United": "Newcastle Utd", "Tottenham Hotspur": "Tottenham", "West Ham United": "West Ham", "Wolverhampton Wanderers": "Wolves"} 
mapping = MissingDict(**map_values)
combined["new_team"] = combined["team"].map(mapping)
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])
merged
# Out:
#      actual_x  prediction_x       date                   team_x  \
# 0           1             1 2022-03-06                  Arsenal
# 1           1             1 2022-03-06                  Arsenal
# 2           1             1 2022-03-06                  Arsenal
# 3           1             1 2022-03-06                  Arsenal
# 4           1             0 2022-03-13                  Arsenal
# ..        ...           ...        ...                      ...
# 979         0             0 2022-05-15  Wolverhampton Wanderers
# 980         0             0 2022-05-22  Wolverhampton Wanderers
# 981         0             0 2022-05-22  Wolverhampton Wanderers
# 982         0             0 2022-05-22  Wolverhampton Wanderers
# 983         0             0 2022-05-22  Wolverhampton Wanderers
#
#          opponent_x result_x new_team_x  actual_y  prediction_y  \
# 0           Watford        W    Arsenal         0             0
# 1           Watford        W    Arsenal         0             0
# 2           Watford        W    Arsenal         0             0
# 3           Watford        W    Arsenal         0             0
# 4    Leicester City        W    Arsenal         0             1
# ..              ...      ...        ...       ...           ...
# 979    Norwich City        D     Wolves         0             0
# 980       Liverpool        L     Wolves         1             0
# 981       Liverpool        L     Wolves         1             0
# 982       Liverpool        L     Wolves         1             0
# 983       Liverpool        L     Wolves         1             0
#
#              team_y opponent_y result_y      new_team_y
# 0           Watford    Arsenal        L         Watford
# 1           Watford    Arsenal        L         Watford
# 2           Watford    Arsenal        L         Watford
# 3           Watford    Arsenal        L         Watford
# 4    Leicester City    Arsenal        L  Leicester City
# ..              ...        ...      ...             ...
# 979    Norwich City     Wolves        D    Norwich City
# 980       Liverpool     Wolves        W       Liverpool
# 981       Liverpool     Wolves        W       Liverpool
# 982       Liverpool     Wolves        W       Liverpool
# 983       Liverpool     Wolves        W       Liverpool
#
# [984 rows x 13 columns]

# %%
merged[(merged["prediction_x"] == 1) & (merged["prediction_y"] ==0)]["actual_x"].value_counts()
# Out:
# 1    140
# 0     58
# Name: actual_x, dtype: int64

# %%
140/198
# Out:
# 0.7070707070707071
